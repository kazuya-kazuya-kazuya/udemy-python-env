# %%
s = """\
AAA
BBB
CCC
DDD
"""
# with open('test.txt', 'w') as f:
#     f.write(s)

with open('test.txt', 'r') as f:
    # print(f.read())

    # while True:
    #     line = f.readline()
    #     print(line)
    #     if not line:
    #         break
    print(f.tell())
    print(f.read(2))
    f.seek(5)
    print(f.read(1))
    f.seek(14)
    print(f.read(1))
    f.seek(15)
    print(f.read(1))
# Out:
# 0
# AA
# B
# D
