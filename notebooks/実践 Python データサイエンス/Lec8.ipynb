# %%
import numpy as np

# %%
arr1 = np.array([[1, 2, 3, 4], [8, 9, 10, 11]])
arr1
# Out:
# array([[ 1,  2,  3,  4],
#        [ 8,  9, 10, 11]])

# %%
arr1*arr1
# Out:
# array([[  1,   4,   9,  16],
#        [ 64,  81, 100, 121]])

# %%
arr1-arr1
# Out:
# array([[0, 0, 0, 0],
#        [0, 0, 0, 0]])

# %%
1 / arr1
# Out:
# array([[1.        , 0.5       , 0.33333333, 0.25      ],
#        [0.125     , 0.11111111, 0.1       , 0.09090909]])
